# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv(r'/Users/pavan.garigipati/NIT_DatascienceAndAI/archive/movie.csv')
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
tags = pd.read_csv(r'/Users/pavan.garigipati/NIT_DatascienceAndAI/archive/tag.csv', sep=',')
tags.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
ratings = pd.read_csv(r'/Users/pavan.garigipati/NIT_DatascienceAndAI/archive/rating.csv', sep=',', parse_dates=['timestamp'])
ratings.head()
# Out:
#    userId  movieId  rating           timestamp
# 0       1        2     3.5 2005-04-02 23:53:47
# 1       1       29     3.5 2005-04-02 23:31:16
# 2       1       32     3.5 2005-04-02 23:33:39
# 3       1       47     3.5 2005-04-02 23:32:07
# 4       1       50     3.5 2005-04-02 23:29:40

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465564 rows x 3 columns]

# %%
tags.iloc[0]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
tags.iloc[0]
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0 = tags.iloc[0]
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0.index
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: 0, dtype: object

# %%
row_0['userId']
# Out:
# 18

# %%
'rating' in row_0
# Out:
# False

# %%
'userId' in row_0
# Out:
# True

# %%
row_0.name
# Out:
# 0

# %%
row_0.movieId
# Out:
# 4141

# %%
row_0 = row_0.rename('firstRow')
row_0
# Out:
# userId              18
# movieId           4141
# tag        Mark Waters
# Name: firstRow, dtype: object

# %%
row_0.name
# Out:
# 'firstRow'

# %% [markdown]
# # DataFrames

# %%
tags.head()
# Out:
#    userId  movieId            tag
# 0      18     4141    Mark Waters
# 1      65      208      dark hero
# 2      65      353      dark hero
# 3      65      521  noir thriller
# 4      65      592      dark hero

# %%
tags.index
# Out:
# RangeIndex(start=0, stop=465564, step=1)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag'], dtype='object')

# %%
tags.iloc[[0,11,500, 200, 500]] # integer location
# Out:
#      userId  movieId                tag
# 0        18     4141        Mark Waters
# 11       65     1783      noir thriller
# 500     342    55908  entirely dialogue
# 200     129    55280        dork people
# 500     342    55908  entirely dialogue

# %%
tags.iloc[ np.random.randint(10, 25, 5)]
# Out:
#     userId  movieId                tag
# 19      65     5135          bollywood
# 14      65     2353  conspiracy theory
# 20      65     6539           treasure
# 14      65     2353  conspiracy theory
# 23      65     7318              jesus

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating
# 0       1        2     3.5
# 1       1       29     3.5

# %%
ratings['rating'].describe()
# Out:
# count    2.000026e+07
# mean     3.525529e+00
# std      1.051989e+00
# min      5.000000e-01
# 25%      3.000000e+00
# 50%      3.500000e+00
# 75%      4.000000e+00
# max      5.000000e+00
# Name: rating, dtype: float64

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings['rating'].mean()
# Out:
# 3.5255285642993797

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
ratings['rating'].min()
# Out:
# 0.5

# %%
ratings['rating'].max()
# Out:
# 5.0

# %%
ratings['rating'].std()
# Out:
# 1.051988919275684

# %%
ratings['rating'].mode()
# Out:
# 0    4.0
# Name: rating, dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = ratings['rating'] > 10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# False

# %%
filter2 = ratings['rating'] > 0
filter2.all()
# Out:
# True

# %% [markdown]
# # Data Cleaning: Handling Missing Data

# %%
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.isnull().any().any()
# Out:
# False

# %%
ratings.shape
# Out:
# (20000263, 3)

# %%
ratings.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465564, 3)

# %%
tags.isnull().any().any()
# Out:
# True

# %%
tags = tags.dropna()
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465548 rows x 3 columns]

# %%
tags.isnull().any().any()
# Out:
# False

# %%
tags.shape
# Out:
# (465548, 3)

# %% [markdown]
# # Data Visualization

# %%
# %matplotlib inline

ratings.hist(column='rating', figsize=(10,5))
plt.show()

# %%
ratings.boxplot(column='rating', figsize=(10,5))
plt.show()

# %% [markdown]
# # Slicing Out Columns

# %%
tags['tag'].head()
# Out:
# 0      Mark Waters
# 1        dark hero
# 2        dark hero
# 3    noir thriller
# 4        dark hero
# Name: tag, dtype: object

# %%
tags
# Out:
#         userId  movieId            tag
# 0           18     4141    Mark Waters
# 1           65      208      dark hero
# 2           65      353      dark hero
# 3           65      521  noir thriller
# 4           65      592      dark hero
# ...        ...      ...            ...
# 465559  138446    55999        dragged
# 465560  138446    55999  Jason Bateman
# 465561  138446    55999         quirky
# 465562  138446    55999            sad
# 465563  138472      923  rise to power
#
# [465548 rows x 3 columns]

# %%
movies[['title', 'genres']].head()
# Out:
#                                 title  \
# 0                    Toy Story (1995)
# 1                      Jumanji (1995)
# 2             Grumpier Old Men (1995)
# 3            Waiting to Exhale (1995)
# 4  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ratings[-10:]
# Out:
#           userId  movieId  rating
# 20000253  138493    60816     4.5
# 20000254  138493    61160     4.0
# 20000255  138493    65682     4.5
# 20000256  138493    66762     4.5
# 20000257  138493    68319     4.5
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5

# %%
tag_counts = tags['tag'].value_counts()
tag_counts
# Out:
# tag
# sci-fi                           3384
# based on a book                  3281
# atmospheric                      2917
# comedy                           2779
# action                           2657
#                                  ...
# Paul Adelstein                      1
# the wig                             1
# killer fish                         1
# genetically modified monsters       1
# topless scene                       1
# Name: count, Length: 38643, dtype: int64

# %%
tag_counts[-10:]
# Out:
# tag
# missing child                    1
# Ron Moore                        1
# Citizen Kane                     1
# mullet                           1
# biker gang                       1
# Paul Adelstein                   1
# the wig                          1
# killer fish                      1
# genetically modified monsters    1
# topless scene                    1
# Name: count, dtype: int64

# %%
tag_counts[:10].plot(kind='bar', figsize=(10,5))
plt.xlabel('Generis')
plt.show()

# %%
tag_counts[:10].plot(kind='pie', figsize=(10,5))
plt.show()

# %%
tag_counts[:10].plot(kind='line', figsize=(10,5))
plt.xlabel('Generes')
plt.show()
