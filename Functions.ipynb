# %%
import math; # math is a module it has all the functionality related to mathmetial operations.
math.sqrt(25)
# Out:
# 5.0

# %%
print(math.pow(3,2))
# Out:
# 9.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
import math as m
m.sqrt(25)
# Out:
# 5.0

# %%
m.sqrt(10)
# Out:
# 3.1622776601683795

# %%
from math import sqrt, pow
print(sqrt(25))
print(pow(3,2))
print(ceil(4.5)) # ceil is not imported as it wont work.
# Out:
# 5.0
# 9.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 print(sqrt(25))
#       3 print(pow(3,2))
# ----> 4 print(ceil(4.5))
#
# NameError: name 'ceil' is not defined

# %%
from math import sqrt, pow, ceil
print(sqrt(25))
print(pow(3,2))
print(ceil(4.5))
# Out:
# 5.0
# 9.0
# 5

# %% [markdown]
# # input function

# %%
x = input("Please enter a number")
x
# Out:
# Please enter a number 5
# '5'

# %%
x = input("Please enter first number")
y = input("Please enter second number")
x + y
# Out:
# Please enter first number 10
# Please enter second number 20
# '1020'

# %%
x = int(input("Please enter first number"))
y = int(input("Please enter second number"))
x + y
# Out:
# Please enter first number 10
# Please enter second number 20
# 30

# %%
x = input("Please enter first number").split()
# Out:
# Please enter first number 2222
