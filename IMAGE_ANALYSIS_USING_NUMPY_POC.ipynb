# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#from PIL import Image # method1 : Python Imaging Library
#import PIL.Image as Image 
import PIL.Image

# %%
#img = Image.open(r'/Users/pavan.garigipati/Desktop/Screenshot 2025-06-16 at 11.34.44 AM.png')
#img

img = PIL.Image.open(r'/Users/pavan.garigipati/Desktop/Screenshot 2025-06-16 at 11.34.44 AM.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1800>

# %%
type(img)
# Out:
# PIL.PngImagePlugin.PngImageFile
