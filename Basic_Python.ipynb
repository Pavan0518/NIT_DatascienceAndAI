# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavan0518/NIT_DatascienceAndAI/blob/main/Basic_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
v = 5
v
# Out:
# 5

# %%
id(v)
# Out:
# 10757864

# %%
5 = v
# Out:
#   File "/tmp/ipython-input-29-237110408.py", line 1
#     5 = v
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
v2 = 10
V2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-51-3821565104.py in <cell line: 0>()
#       1 v2 = 10
# ----> 2 V2
#
# NameError: name 'V2' is not defined

# %%
v* = 8
v*

# %%
v_ = 10
v_

# %%
import keyword
keyword.kwlist

# %%
len(keyword.kwlist)

# %%
prefix = 'py'
prefix + 'thon'

# %%
spam = 1
text ="it's inside quote."
spam
text

# %%
2 + 2

# %%
50 - 5 * 6

# %%
(50 - 5 * 6) / 4

# %%
8 / 5

# %%
13 / 7

# %%
13 // 7
# Out:
# 1

# %%
13 % 7
# Out:
# 6

# %%
5 ** 2
# Out:
# 25

# %%
width = 20
height = 5 * 9
width * height
# Out:
# 900

# %%
_
# Out:
# 900

# %%
n = 113.041235
n
# Out:
# 113.041235

# %%
_
# Out:
# 113.041235

# %%
round(_, 2)
# Out:
# 113.04

# %%
"doesn\'t"
# Out:
# "doesn't"

# %%
print('c:\some\name')
# Out:
# c:\some
# ame

# %%
print(r'c:\some\name')
# Out:
# c:\some\name

# %%
print(""" -H hostname""")
# Out:
#  -H hostname

# %%
3 * 'pavan ' + 4 * 'kumar '
# Out:
# 'pavan pavan pavan kumar kumar kumar kumar '

# %%
word = 'Python'
word[0:2]
# Out:
# 'Py'

# %%
word[2:5]
# Out:
# 'tho'

# %%
word[2:6]
# Out:
# 'thon'

# %%
word[2:9]
# Out:
# 'thon'

# %%
word[-1]
# Out:
# 'n'

# %%
word[-5]
# Out:
# 'y'

# %%
word[-6]
# Out:
# 'P'

# %%
word[-7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-50-3612666644.py in <cell line: 0>()
# ----> 1 word[-7]
#
# IndexError: string index out of range

# %%
word[:2]

# %%
word[:3]

# %%
word

# %%
word[2:]

# %%
word[-2:]

# %%
word[:-2]

# %%
word[0:-2]

# %%
word[1:-2]

# %%
c = 10 + 11j
c

# %%
c = 5 + 10j
d = 15 + 12j
print(c)
print(d)
print(c + d)

# %%
a = 5
a

# %%
type(5)

# %%
s = "abc"
print(s)

# %%
type(11 + 10j)

# %%
num1 = 10
num2 = 20
print(num1 + num2)
print('The sum of two numbers ', num1, ' and ' , num2 , ' is ' , (num1 + num2))

# %%
print('The sum of two numbers {} and {} is {}'.format(num1, num2, (num1 + num2)))

# %%
num3 = 30
print('The sum of three numbers {}, {} and {} is {}'.format(num1, num2, num3, (num1 + num2 + num3)))

# %%
b1 = True
b2 = False
print(b1)
print(b2)

# %%
1 * b1 + 10

# %%
type(b1)

# %%
1 * b1 / 5

# %%
 b1 + b2

# %%
int(b1)

# %%
int(b2)

# %%
True + True

# %%
True + False

# %%
False - True

# %%
True + 20 - (5 * True)

# %%
def wish():
  print('Hello World.')

wish()

# %%
class nit():
  def hello():
    print("Hello")

nit.hello()

# %%
p = q = r = 20
print(id(p))
print(id(q))
print(id(r))
# same address

# %%
p1,q1,r1 = 20

# %%
p1,q1,r1 = 20,21,22
print(id(p1))
print(id(q1))
print(id(r1))
# stores differenrt address

# %%
s= 'hello python'
s

# %%
len(s)

# %%
s[0]

# %%
s[-1]

# %%
s[-6:-1]

# %%
s[:]

# %%
s[13]

# %%
s[0:5]

# %%
s[6:9]

# %%
s[-5:-1]

# %%
s

# %%
s[1:]

# %%
s[:5]

# %%
s[2:7]

# %%
s[2:]

# %%
s[:6]

# %%
s

# %%
s[::-1]

# %%
s[2:10:2]

# %%
s[0:13:3]

# %%
s[0:10:5]

# %%
s1 = 'nareshit'
s1

# %%
s1[0:10]

# %%
s[::5]

# %%
bool([])
# Out:
# False

# %%
x = {}
type(x)
# Out:
# dict

# %%
s = set()
type(s)
s.ad
# Out:
# set

# %%
s = [0,1,2,3]
type(s)
# Out:
# list

# %%
S = {1, 2, 2, 3}
print(len(S))
# Out:
# 3

# %%
a = {1,2,3}
type(a)
a.add(4)
a.add(4)
print(a)
# Out:
# {1, 2, 3, 4}

# %%
my_list = [1, 2]
my_list.append([3, 4])
print(my_list)
# Out:
# [1, 2, [3, 4]]

# %%
list("abc")
# Out:
# ['a', 'b', 'c']

# %%
import numpy as np
a = np.array([[1, 2, 3], [4, 5, 6]])
print(a.shape)
a.size
np.eye(3)
# Out:
# (2, 3)
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
type(type(10))
# Out:
# type

# %%
set([1, 2, 3]) == set([3, 1, 2])
# Out:
# True

# %%
s = np.array([1.0, 2.0])

# %%
type(s)
# Out:
# numpy.ndarray
