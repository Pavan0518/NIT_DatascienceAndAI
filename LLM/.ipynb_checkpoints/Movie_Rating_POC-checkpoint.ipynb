# %%
import pandas as pd

# %%
movies = pd.read_csv(r'Movie-Rating.csv')
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
pd.__version__
# Out:
# '2.2.2'

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.columns = ['Film', 'Gener', 'CriticRating', 'AudienceRatings',
       'BudgetMillions', 'Year']

# %%
movies.head(1)
# Out:
#                     Film   Gener  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer   Comedy            87               81
#
#    BudgetMillions  Year
# 0               8  2009

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    object
#  1   Gener            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.Film = movies.Film.astype('category')
movies.Film
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: category
# Categories (559, object): ['(500) Days of Summer ', '10,000 B.C.', '12 Rounds ', '127 Hours', ..., 'Youth in Revolt', 'Zodiac', 'Zombieland ', 'Zookeeper']

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions         Year
# count    559.000000       559.000000      559.000000   559.000000
# mean      47.309481        58.744186       50.236136  2009.152057
# std       26.413091        16.826887       48.731817     1.362632
# min        0.000000         0.000000        0.000000  2007.000000
# 25%       25.000000        47.000000       20.000000  2008.000000
# 50%       46.000000        58.000000       35.000000  2009.000000
# 75%       70.000000        72.000000       65.000000  2010.000000
# max       97.000000        96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Gener            559 non-null    object
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(1), int64(4), object(1)
# memory usage: 43.6+ KB

# %%
movies.Gener = movies.Gener.astype('category')
movies.Gener
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Gener, Length: 559, dtype: category
# Categories (7, object): ['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance', 'Thriller']

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Gener            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    int64
# dtypes: category(2), int64(4)
# memory usage: 40.1 KB

# %%
movies.Year = movies.Year.astype('category')
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Film             559 non-null    category
#  1   Gener            559 non-null    category
#  2   CriticRating     559 non-null    int64
#  3   AudienceRatings  559 non-null    int64
#  4   BudgetMillions   559 non-null    int64
#  5   Year             559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRatings  BudgetMillions
# count    559.000000       559.000000      559.000000
# mean      47.309481        58.744186       50.236136
# std       26.413091        16.826887       48.731817
# min        0.000000         0.000000        0.000000
# 25%       25.000000        47.000000       20.000000
# 50%       46.000000        58.000000       35.000000
# 75%       70.000000        72.000000       65.000000
# max       97.000000        96.000000      300.000000

# %%
from matplotlib import pyplot as plt # visualization
import seaborn as sns # advance visualization

import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='scatter')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='kde')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='hex')

# %%
j = sns.jointplot(data = movies, x = 'CriticRating', y = 'AudienceRatings', kind='reg')

# %%
m1 = sns.distplot(movies.AudienceRatings)

# %%
sns.set_style('darkgrid')

# %%
m2 = sns.distplot(movies.AudienceRatings, bins = 15)

# %%
n1 = plt.hist(movies.AudienceRatings, bins = 15)

# %%
sns.set_style('white')

n1 = plt.hist(movies.AudienceRatings, bins = 20)

# %%
n1 = plt.hist(movies.CriticRating, bins=20)

# %%
plt.hist(movies.BudgetMillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(movies[movies.Gener == 'Drama'].BudgetMillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movies.head()
# Out:
#                     Film      Gener  CriticRating  AudienceRatings  \
# 0  (500) Days of Summer      Comedy            87               81
# 1            10,000 B.C.  Adventure             9               44
# 2             12 Rounds      Action            30               52
# 3              127 Hours  Adventure            93               84
# 4              17 Again      Comedy            55               70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Gener == 'Action'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Gener == 'Thriller'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Gener == 'Drama'].BudgetMillions, bins = 20)
plt.hist(movies[movies.Gener == 'Comedy'].BudgetMillions, bins = 20)
plt.legend()
plt.show()

# %%
plt.hist([
            movies[movies.Gener == 'Action'].BudgetMillions,
            movies[movies.Gener == 'Drama'].BudgetMillions, 
            movies[movies.Gener == 'Thriller'].BudgetMillions, 
            movies[movies.Gener == 'Comedy'].BudgetMillions
         ],
         bins = 20, stacked = True)
plt.show()

# %%
# if you have 100 categories you cannot copy & paste all the things

for gen in movies.Gener.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False)

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',\
                 fit_reg=False, hue = 'Gener')

# %%
vis1 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRatings',
                 fit_reg=False, hue = 'Gener', aspect=1)

# %%
movies
# Out:
#                       Film      Gener  CriticRating  AudienceRatings  \
# 0    (500) Days of Summer      Comedy            87               81
# 1              10,000 B.C.  Adventure             9               44
# 2               12 Rounds      Action            30               52
# 3                127 Hours  Adventure            93               84
# 4                17 Again      Comedy            55               70
# ..                     ...        ...           ...              ...
# 554          Your Highness     Comedy            26               36
# 555        Youth in Revolt     Comedy            68               52
# 556                 Zodiac   Thriller            89               73
# 557            Zombieland      Action            90               87
# 558              Zookeeper     Comedy            14               42
#
#      BudgetMillions  Year
# 0                 8  2009
# 1               105  2008
# 2                20  2009
# 3                18  2010
# ...

# %%
#k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings)

# where do u find more density and how density is distibuted across from the the chat 
# center point is kernal this is calld KDE & insteade of dots it visualize like this
# we can able to clearly see the spread at the audience ratings
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 k1 = sns.kdeplot(movies.CriticRating, movies.AudienceRatings)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
# k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 k1 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds')
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#k2 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 k2 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.set_style('dark')
#k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 2
#       1 sns.set_style('dark')
# ----> 2 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,shade_lowest=False,cmap='Greens_r')
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
sns.set_style('dark')
#k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 2
#       1 sns.set_style('dark')
# ----> 2 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating)
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#subplots

f, ax = plt.subplots(1,2, figsize =(12,6))
#f, ax = plt.subplots(3,3, figsize =(12,6))

# %%
f, axes = plt.subplots(1,2, figsize =(12,6))

k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 3
#       1 f, axes = plt.subplots(1,2, figsize =(12,6))
# ----> 3 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0])
#       4 k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[1])
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
axes
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
#Box plots - 

w = sns.boxplot(data=movies, x='Gener', y = 'CriticRating')

# %%
#violin plot

z = sns.violinplot(data=movies, x='Gener', y = 'CriticRating')

# %%
w1 = sns.boxplot(data=movies[movies.Gener == 'Drama'], x='Year', y = 'CriticRating')

# %%
z = sns.violinplot(data=movies[movies.Gener == 'Drama'], x='Year', y = 'CriticRating')

# %%
# Createing a Facet grid

# %%
g =sns.FacetGrid (movies, row = 'Gener', col = 'Year', hue = 'Gener') #kind of subplots

# %%
plt.scatter(movies.CriticRating,movies.AudienceRatings)

# %%
g =sns.FacetGrid (movies, row = 'Gener', col = 'Year', hue = 'Gener')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings' ) #scatterplots are mapped in facetgrid

# %%
# you can populated any type of chat. 

g =sns.FacetGrid (movies, row = 'Gener', col = 'Year', hue = 'Gener')
g = g.map(plt.hist, 'BudgetMillions') #scatterplots are mapped in facetgrid

# %%
#
g =sns.FacetGrid (movies, row = 'Gener', col = 'Year', hue = 'Gener')
kws = dict(s=50, linewidth=0.5,edgecolor='black')
g = g.map(plt.scatter, 'CriticRating', 'AudienceRatings',**kws ) #scatterplots are mapped in facetgrid

# %%
# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('darkgrid')
f, axes = plt.subplots (2,2, figsize = (15,15))

k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0,0])
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

z = sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y = 'CriticRating', ax=axes[1,0])

k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings,shade = True,shade_lowest=False,cmap='Reds',ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings,cmap='Reds',ax = axes[1,1])

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[81], line 7
#       4 sns.set_style('darkgrid')
#       5 f, axes = plt.subplots (2,2, figsize = (15,15))
# ----> 7 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings,ax=axes[0,0])
#       8 k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRatings,ax = axes[0,1])
#      10 k1.set(xlim=(-20,160))
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given

# %%
# How can you style your dashboard  using different color map

# python is not vectorize programming language
# Building dashboards (dashboard - combination of chats)

sns.set_style('dark',{'axes.facecolor':'black'})
f, axes = plt.subplots (2,2, figsize = (15,15))

#plot [0,0]
k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings, \
                 shade = True, shade_lowest=True,cmp = 'inferno', \
                 ax = axes[0,0])
k1b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, \
                 cmap = 'cool',ax = axes[0,0])

#plot [0,1]
k2 = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                 shade=True, shade_lowest=True, cmap='inferno',\
                 ax = axes[0,1])
k2b = sns.kdeplot(movies.BudgetMillions,movies.CriticRating,\
                  cmap = 'cool', ax = axes[0,1])

#plot[1,0]
z = sns.violinplot(data=movies[movies.Genre=='Drama'], \
                   x='Year', y = 'CriticRating', ax=axes[1,0])

#plot[1,1]
k4 = sns.kdeplot(movies.CriticRating,movies.AudienceRatings, \
                 shade = True,shade_lowest=False,cmap='Blues_r', \
                 ax=axes[1,1])

k4b = sns.kdeplot(movies.CriticRating, movies.AudienceRatings, \
                  cmap='gist_gray_r',ax = axes[1,1])


k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 10
#       7 f, axes = plt.subplots (2,2, figsize = (15,15))
#       9 #plot [0,0]
# ---> 10 k1 = sns.kdeplot(movies.BudgetMillions,movies.AudienceRatings, \
#      11                  shade = True, shade_lowest=True,cmp = 'inferno', \
#      12                  ax = axes[0,0])
#      13 k1b = sns.kdeplot(movies.BudgetMillions, movies.AudienceRatings, \
#      14                  cmap = 'cool',ax = axes[0,0])
#      16 #plot [0,1]
#
# TypeError: kdeplot() takes from 0 to 1 positional arguments but 2 positional arguments (and 1 keyword-only argument) were given
