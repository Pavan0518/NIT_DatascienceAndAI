# %%
import matplotlib.pyplot as plt
import numpy as np

xpos = np.array([0,10])
ypos = np.array([0,100])

plt.plot(xpos, ypos, ls="--", ms="10", marker="^")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpos = np.array([0,10])
ypos = np.array([0,100])

plt.plot(xpos, ypos, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpos = np.array([0,2,4,6,72,3,5])
ypos = np.array([0,70,20,50,30,11,12])

plt.plot(xpos, ypos, marker="o")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpos = np.array([0,2,4,6,72,3,5])
ypos = np.array([0,70,20,50,30,11,12])

plt.plot(xpos, ypos, marker="*")
plt.show()
