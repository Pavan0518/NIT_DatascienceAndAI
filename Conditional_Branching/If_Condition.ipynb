# %%
if True:
    print('Hello')
# Out:
# Hello

# %%
if True:
    print('Hello')
print('Hello2')
# Out:
# Hello
# Hello2

# %%
if False:
    print('Bye')

# %%
if True:
    print('In datascience.')
else:
    print('bye for now.')
# Out:
# In datascience.

# %%
if False:
    print('In datascience.')
else:
    print('bye for now.')
# Out:
# bye for now.

# %%
x = 4
r = x % 2
if r == 0:
    print('Even number.')
# Out:
# Even number.

# %%
x = 5
r = x % 2
if r == 0:
    print('Even number.')

if r == 1:
    print('Odd number.')
# Out:
# Odd number.

# %%
x = 4
r = x % 2
if r == 0:
    print('Even number.')

if r == 1:
    print('Odd number.')
# Out:
# Even number.

# %%
x = 6
r = x % 2
if r == 0:
    print('Even number.')

if r == 1:
    print('Odd number.')
# Out:
# Even number.

# %%
x = 6
r = x % 2
if r == 0:
    print('Even number.')
else:
    print('Odd number.')
# Out:
# Even number.

# %%
x = 6
r = x % 2
if r == 0:
    print('Even number.')
print('Odd number.')
# Out:
# Even number.
# Odd number.

# %%
x = 6
r = x % 2
if r == 0:print('Even number.')
else:print('Odd number.')
# Out:
# Even number.

# %%
x = 5
r = x % 2
if r == 0:print('Even number.')
else:print('Odd number.')
# Out:
# Odd number.

# %%
x = 10
r = x % 2
if r == 0:
    print('Even number.')

if r != 0:
    print('Odd number.')
# Out:
# Even number.

# %%
x = 9
r = x % 2
if r == 0:
    print('Even number.')

if r != 0:
    print('Odd number.')
# Out:
# Odd number.

# %% [markdown]
# # Nested if

# %%
x = 3
r = x % 2
if r == 0:
    print('Even number.')
    if x > 5:
        print('Greater number.')
else:
    print('Odd number.')
# Out:
# Odd number.

# %%
x = 4
r = x % 2
if r == 0:
    print('Even number.')
    if x > 5:
        print('Greater number.')
else:
    print('Odd number.')
# Out:
# Even number.

# %%
x = 6
r = x % 2
if r == 0:
    print('Even number.')
    if x > 5:
        print('Greater number.')
else:
    print('Odd number.')
# Out:
# Even number.
# Greater number.

# %%
x = 4
r = x % 2
if r == 0:
    print('Even number.')
    if x > 5:
        print('Greater number.')
    else: print('Less number.')
else:
    print('Odd number.')
# Out:
# Even number.
# Less number.

# %%
x = 4

if x == 1:
    print('One')
if x == 2:
    print('Two')
if x == 3:
    print('Three')
if x == 4:
    print('Four')
# Out:
# Four

# %%
x = 4

if x == 1:
    print('One')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
# Out:
# Four

# %%
x = 3

if x == 1:
    print('One')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
# Out:
# Three

# %%
x = 4

if x == 1:
    print('One')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
# Out:
# Four

# %%
x = 4

if x == 1:
    print('One')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
else: print('Number not found.')
# Out:
# Four

# %%
x = 14

if x == 1:
    print('One')
elif x == 2:
    print('Two')
elif x == 3:
    print('Three')
elif x == 4:
    print('Four')
else: print('Number not found.')
# Out:
# Number not found.
